# %%
################# Definições
import string
import re
import time
start_time = time.perf_counter()
frase = ""
dicbinario = {"100000":" ", "100010":"1", "100111":"2", "101101":"3", "101110":"4", "101100":"5", "1000001":"A", "1000010":"B", "1000011":"C", "1000100":"D", "1000101":"E", "1000110":"F", "1000111":"G", "1001000":"H", "1001001":"I", "1001010":"J", "1001011":"K", "1001100":"L", "1001101":"M", "1001110":"N", "1001111":"O", "1010000":"P", "1010001":"Q", "1010010":"R", "1010011":"S", "1010100":"T", "1010101":"U", "1010110":"V", "1010111":"W", "1011000":"X", "1011001":"Y", "1011010":"Z"}
Dic_Top = "500.txt" 
Dic_Final = "words_alpha.txt"
 
################# (1) Transformação do binário em letras, realizando separação por letra e palavra

bins = frase.split()
binario = "".join(dicbinario[b] for b in bins)
palavras = binario.split()
letras = [list(palavras) for palavras in binario]
print("Letras minúsculas = decifradas / Letras maiúsculas = cifradas")
print("Início da cifra:\n", binario)
binariosave = binario
ponteiro = 1
score = 0
while score < 0.8 and ponteiro < 7:
    binario = binariosave
    letras = [list(palavras) for palavras in binario]
    letras = [c for c in letras if c != ['']]
    letra = [c[0] for c in letras]
    contagem = {}
    for letr in letra:
        if letr == ' ':
            continue
        if letr not in contagem:
            contagem[letr] = 1
        else:
            contagem[letr] += 1
    mais_comum = None
    maior_qtd = 0
    mapa = {}
    for letr, qtd in contagem.items():
        if qtd > maior_qtd:
            maior_qtd = qtd
            mais_comum = letr
            
################# (2) Identificação da letra mais comum
    
    print(ponteiro)
    for c in letras:
        if c[0] == mais_comum:
            if ponteiro == 1:
                c[0] = 'e'
                binario = binario.replace(mais_comum, "e")
                palavras= [d.replace(mais_comum, "e") for d in palavras]
            if ponteiro == 2:              
                def mapa_string(s, mapa):
                    return ''.join(mapa.get(ch, ch) for ch in s)
                seq = [ch for ch in letra if ch != ' ']
                par_letras = {}
                for i in range(len(seq) - 1):
                    a, b = seq[i], seq[i+1]
                    if not (a.isupper() and b.isupper()):
                        continue
                    par_letras[(a, b)] = par_letras.get((a, b), 0) + 1
                
                if par_letras:
                    mais_comum_par = max(par_letras, key=par_letras.get)
                    a, b = mais_comum_par
                    mapa[a] = 't'
                    mapa[b] = 'h'
                    print(f"Par de letras mais comum: {a}{b} - 'th'")
                
                    for c in letras:
                        if c[0] in mapa:
                            c[0] = mapa[c[0]]
                    binario = mapa_string(binario, mapa)
                    palavras = [mapa_string(p, mapa) for p in palavras]
                else:
                    print("Nenhum par de letras relevante encontrado.")
                
            if ponteiro == 3:
                c[0] = 't'
                binario = binario.replace(mais_comum, "a")
                palavras= [d.replace(mais_comum, "a") for d in palavras]
            if ponteiro == 4:
                c[0] = 'a'
                binario = binario.replace(mais_comum, "o")
                palavras= [d.replace(mais_comum, "o") for d in palavras]
            if ponteiro == 5:
                c[0] = 'o'
                binario = binario.replace(mais_comum, "i")
                palavras= [d.replace(mais_comum, "i") for d in palavras]
            if ponteiro == 6:
                c[0] = 'i'
                binario = binario.replace(mais_comum, "n")
                palavras= [d.replace(mais_comum, "n") for d in palavras]
    print("Cifra após (2):\n", binario)
 
############## (3) Com o dicionário de palavras mais populares, identificar letras baseando-se em palavras mais comuns
     
    def dicio_por_tamanho(caminho):
        by_len = {}
        with open(caminho, encoding="utf-8") as f:
            for L in f:
                w = L.strip().lower()
                if not w:
                    continue
                by_len.setdefault(len(w), []).append(w)
        return by_len
     
    def aplica_mapa(frase, mapa):
        return "".join(mapa.get(c, c) for c in frase)
     
    def encaixa_com_mapa(palavra_cif, candidata, mapa):
        local_map = {}
        used_vals = set(mapa.values())
        for cif_char, cand_char in zip(palavra_cif, candidata):
            if cif_char.islower():
                if cand_char != cif_char:
                    return False
            else:  
                if cif_char in mapa:
                    if mapa[cif_char] != cand_char:
                        return False
                else:
                    if cif_char in local_map:
                        if local_map[cif_char] != cand_char:
                            return False
                    else:
                        if cand_char in used_vals:
                            return False
                        local_map[cif_char] = cand_char
        return True
     
    def poss_para_palavra(palavra_cif, dicio_by_len, mapa):
        if palavra_cif.islower():
            return [palavra_cif] 
        poss = dicio_by_len.get(len(palavra_cif), [])
        return [w for w in poss if encaixa_com_mapa(palavra_cif, w, mapa)]
     
    def certezas(binario, dicio_by_len, mapa_inicial=None):
        if mapa_inicial is None:
            mapa_inicial = {}
        mapa = dict(mapa_inicial)
        palavras = binario.split()
     
        progresso = True
        rodada = 0
        while progresso:
            rodada += 1
            progresso = False
            print(f"Rodada {rodada}")
            poss_list = []
            for p in palavras:
                cand = poss_para_palavra(p, dicio_by_len, mapa)
                poss_list.append(cand)
                status = f"{p:>8} -{len(cand)} possibilidades"
                if len(cand) <= 8:
                   status += f": {cand}"
                   print(status)
     
            for idx, cand in enumerate(poss_list):
                p_cif = palavras[idx]
                if len(cand) == 1 and any(ch.isupper() for ch in p_cif):
                    chosen = cand[0]
                    novas = {}
                    conflitante = False
                    for cif_char, plain_char in zip(p_cif, chosen):
                        if cif_char.isupper():
                            if cif_char in mapa:
                                if mapa[cif_char] != plain_char:
                                    conflitante = True
                                    break
                            else:
                                if plain_char in mapear_valores(mapa) and cif_char not in mapa:
                                    conflitante = True
                                    break
                                novas[cif_char] = plain_char
                    if conflitante:
                        print(f"  Ignorando {p_cif} como {chosen} por causa de conflitos")
                        continue
                    if novas:
                        print(f"  Identificando {p_cif} como {chosen} e aplicando no mapa {novas}")
                        mapa.update(novas)
                        progresso = True
                    else:
                        pass
        decif = aplica_mapa(binario, mapa)
        return decif, mapa
     
    def mapear_valores(mapa):
        return set(mapa.values())
     
    if __name__ == "__main__":
        dicio_by_len = dicio_por_tamanho(Dic_Top)
        mapa_inicial = mapa
     
        decifrada, mapa_final = certezas(binario, dicio_by_len, mapa_inicial)
        print("Mapa em (3):\n", mapa_final)
        print("Cifra após (3):\n", decifrada)
     
################# (4) Com base nas letras já encontradas, repetir o procedimento com um dicionário maior
     
    if __name__ == "__main__":
        dicio_by_len = dicio_por_tamanho(Dic_Final)
        mapa_inicial = mapa_final
     
        decifrada, mapa_final = certezas(binario, dicio_by_len, mapa_inicial)
        print("Mapa em (4):\n", mapa_final)
        print("Solução da cifra após (4):\n", decifrada)

################# (5) Pontuação
############ .
    ultimo_numero = None
    for ch in reversed(decifrada):
        if ch.isdigit():
            ultimo_numero = ch
            break
    if ultimo_numero is not None:
        decifrada = decifrada.replace(ultimo_numero, '.')
        print(f"Último número encontrado: {ultimo_numero}")
    else:
        print("Não há ponto na cifra.")
############ ,
    contagem = {}
    for ch in decifrada:
        if ch.isdigit():
            contagem[ch] = contagem.get(ch, 0) + 1
    if contagem:
        numero_mais_comum = max(contagem, key=contagem.get)
        decifrada = decifrada.replace(numero_mais_comum, ',')
        print(f"Número mais frequente: {numero_mais_comum}")
        print(f"Frase modificada: {decifrada}")
    else:
        print("Nenhum número encontrado na frase.")
############ '
    def substituir_numero_especial(decifrada):
        chars = list(decifrada)
        numero_alvo = None
        for i in range(1, len(chars) - 1):
            if chars[i].isdigit():
                if chars[i - 1].lower() == 't' and chars[i + 1].lower() == 's':
                    numero_alvo = chars[i]
                    break
        if numero_alvo:
            decifrada = decifrada.replace(numero_alvo, "'")
            print(f"Número identificado: {numero_alvo}")
            print(f"Frase modificada: {decifrada}")
            return decifrada
        else:
            print("Nenhum padrão 't[0-9]s' encontrado.")
            return decifrada
    substituir_numero_especial(decifrada)
    
################# (6) Avaliação do resultado

    with open("words_alpha.txt", encoding="utf-8") as f:
        dicionario = set(w.strip().lower() for w in f if w.strip())
    def qualidade_texto(frase, dicionario):
        palavras = re.findall(r"[a-z]+", frase.lower())    
        if not palavras:
            return 0.0, []  
        desconhecidas = [p for p in palavras if p not in dicionario]
        conhecidas = len(palavras) - len(desconhecidas)    
        qualidade = conhecidas / len(palavras)
        return qualidade, desconhecidas        
    score, nao_encontradas = qualidade_texto(decifrada, dicionario)
    print(f"Qualidade: {score:.2%}") 
    print(f"Palavras fora do dicionário: {nao_encontradas}")    
    ponteiro = ponteiro + 1

end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"Tempo de execução: {elapsed_time:.5f} segundos")
# Out:
# Letras minúsculas = decifradas / Letras maiúsculas = cifradas
# Início da cifra:
#  DPRPWWPI IK IFGG WAV BQEDKW EDWKDMT PAD PAW QWRE BQWDTKW   QVH DTKV PVK BFVK RPWVFVU EP IK YKQD PV YPQDE QUQFVED DTK MAWWKVD YPWVK YQMO MKQEKGKEEGS FVDP DTK LQED
# 1
# Cifra após (2):
#  DPRPWWPI Ie IFGG WAV BQEDeW EDWeDMT PAD PAW QWRE BQWDTeW   QVH DTeV PVe BFVe RPWVFVU EP Ie YeQD PV YPQDE QUQFVED DTe MAWWeVD YPWVe YQMO MeQEeGeEEGS FVDP DTe LQED
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ie -6 possibilidades: ['be', 'he', 'we', 'me', 'ie', 're']
#  EDWeDMT -4 possibilidades: ['someone', 'stretch', 'intense', 'stretch']
#  BQWDTeW -7 possibilidades: ['partner', 'forever', 'barrier', 'besides', 'carrier', 'oversee', 'besides']
#       Ie -6 possibilidades: ['be', 'he', 'we', 'me', 'ie', 're']
# MeQEeGeEEGS -0 possibilidades: []
#   Identificando DPRPWWPI como tomorrow e aplicando no mapa {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w'}
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ie -1 possibilidades: ['we']
#     IFGG -5 possibilidades: ['will', 'well', 'wall', 'well', 'will']
#      WAV -7 possibilidades: ['run', 'red', 'run', 'rub', 'rid', 'rip', 'rib']
#   BQEDeW -5 possibilidades: ['center', 'sister', 'hunter', 'filter', 'faster']
#  EDWeDMT -2 possibilidades: ['stretch', 'stretch']
#      PAD -3 possibilidades: ['out', 'out', 'opt']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTeW -1 possibilidades: ['partner']
#     DTeV -3 possibilidades: ['they', 'then', 'teen']
#      PVe -3 possibilidades: ['one', 'one', 'one']
#  RPWVFVU -1 possibilidades: ['morning']
#       Ie -1 possibilidades: ['we']
#       PV -6 possibilidades: ['of', 'on', 'on', 'oh', 'ok', 'ok']
#    YPQDE -2 possibilidades: ['south', 'youth']
#  QUQFVED -5 possibilidades: ['against', 'analyst', 'suspect', 'suspect', 'elegant']
#      DTe -3 possibilidades: ['the', 'tie', 'tie']
#  MAWWeVD -1 possibilidades: ['current']
#    YPWVe -3 possibilidades: ['force', 'force', 'horse']
# MeQEeGeEEGS -0 possibilidades: []
#     FVDP -2 possibilidades: ['into', 'auto']
#      DTe -3 possibilidades: ['the', 'tie', 'tie']
#   Identificando PAW como our e aplicando no mapa {'A': 'u'}
#   Identificando QWRE como army e aplicando no mapa {'Q': 'a', 'E': 'y'}
#   Identificando BQWDTeW como partner e aplicando no mapa {'B': 'p', 'T': 'n'}
#   Ignorando RPWVFVU como morning por causa de conflitos
#   Ignorando MAWWeVD como current por causa de conflitos
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ie -1 possibilidades: ['we']
#     IFGG -4 possibilidades: ['will', 'well', 'well', 'will']
#      WAV -1 possibilidades: ['rub']
#   BQEDeW -0 possibilidades: []
#  EDWeDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTeW -1 possibilidades: ['partner']
#     DTeV -0 possibilidades: []
#      PVe -0 possibilidades: []
#     BFVe -2 possibilidades: ['pile', 'pile']
#  RPWVFVU -0 possibilidades: []
#       EP -0 possibilidades: []
#       Ie -1 possibilidades: ['we']
#     YeQD -6 possibilidades: ['seat', 'heat', 'beat', 'beat', 'heat', 'seat']
#       PV -4 possibilidades: ['of', 'oh', 'ok', 'ok']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTe -0 possibilidades: []
#  MAWWeVD -0 possibilidades: []
#    YPWVe -3 possibilidades: ['force', 'force', 'horse']
# MeQEeGeEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTe -0 possibilidades: []
#     LQED -0 possibilidades: []
#   Identificando WAV como rub e aplicando no mapa {'V': 'b'}
# Rodada 4
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ie -1 possibilidades: ['we']
#     IFGG -4 possibilidades: ['will', 'well', 'well', 'will']
#      WAV -1 possibilidades: ['rub']
#   BQEDeW -0 possibilidades: []
#  EDWeDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTeW -1 possibilidades: ['partner']
#      QVH -0 possibilidades: []
#     DTeV -0 possibilidades: []
#      PVe -0 possibilidades: []
#     BFVe -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -0 possibilidades: []
#       Ie -1 possibilidades: ['we']
#     YeQD -4 possibilidades: ['seat', 'heat', 'heat', 'seat']
#       PV -0 possibilidades: []
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTe -0 possibilidades: []
#  MAWWeVD -0 possibilidades: []
#    YPWVe -0 possibilidades: []
# MeQEeGeEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTe -0 possibilidades: []
#     LQED -0 possibilidades: []
# Mapa em (3):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'B': 'p', 'T': 'n', 'V': 'b'}
# Cifra após (3):
#  tomorrow we wFGG rub payter ytretMn out our army partner   abH tneb obe pFbe morbFbU yo we Yeat ob Yoaty aUaFbyt tne Murrebt Yorbe YaMO MeayeGeyyGS Fbto tne Layt
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ie -1 possibilidades: ['we']
#     IFGG -4 possibilidades: ['well', 'whee', 'will', 'wiss']
#      WAV -1 possibilidades: ['rub']
#   BQEDeW -0 possibilidades: []
#  EDWeDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTeW -1 possibilidades: ['partner']
#      QVH -6 possibilidades: ['abc', 'abd', 'abe', 'abl', 'abs', 'abv']
#     DTeV -0 possibilidades: []
#      PVe -1 possibilidades: ['obe']
#     BFVe -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -1 possibilidades: ['yo']
#       Ie -1 possibilidades: ['we']
#     YeQD -6 possibilidades: ['feat', 'geat', 'heat', 'keat', 'leat', 'seat']
#       PV -1 possibilidades: ['ob']
#    YPQDE -2 possibilidades: ['doaty', 'goaty']
#  QUQFVED -0 possibilidades: []
#      DTe -0 possibilidades: []
#  MAWWeVD -0 possibilidades: []
#    YPWVe -1 possibilidades: ['corbe']
# MeQEeGeEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTe -0 possibilidades: []
#     LQED -0 possibilidades: []
#   Identificando YPWVe como corbe e aplicando no mapa {'Y': 'c'}
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ie -1 possibilidades: ['we']
#     IFGG -4 possibilidades: ['well', 'whee', 'will', 'wiss']
#      WAV -1 possibilidades: ['rub']
#   BQEDeW -0 possibilidades: []
#  EDWeDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTeW -1 possibilidades: ['partner']
#      QVH -5 possibilidades: ['abd', 'abe', 'abl', 'abs', 'abv']
#     DTeV -0 possibilidades: []
#      PVe -1 possibilidades: ['obe']
#     BFVe -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -1 possibilidades: ['yo']
#       Ie -1 possibilidades: ['we']
#     YeQD -0 possibilidades: []
#       PV -1 possibilidades: ['ob']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTe -0 possibilidades: []
#  MAWWeVD -0 possibilidades: []
#    YPWVe -1 possibilidades: ['corbe']
# MeQEeGeEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTe -0 possibilidades: []
#     LQED -0 possibilidades: []
# Mapa em (4):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'B': 'p', 'T': 'n', 'V': 'b', 'Y': 'c'}
# Solução da cifra após (4):
#  tomorrow we wFGG rub payter ytretMn out our army partner   abH tneb obe pFbe morbFbU yo we ceat ob coaty aUaFbyt tne Murrebt corbe caMO MeayeGeyyGS Fbto tne Layt
# Não há ponto na cifra.
# Nenhum número encontrado na frase.
# Nenhum padrão 't[0-9]s' encontrado.
# Qualidade: 41.38%
# Palavras fora do dicionário: ['wfgg', 'payter', 'ytretmn', 'abh', 'tneb', 'pfbe', 'morbfbu', 'ceat', 'coaty', 'auafbyt', 'tne', 'murrebt', 'camo', 'meayegeyygs', 'fbto', 'tne', 'layt']
# 2
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Par de letras mais comum: DP - 'th'
# Cifra após (2):
#  thRhWWhI IK IFGG WAV BQEtKW EtWKtMT hAt hAW QWRE BQWtTKW   QVH tTKV hVK BFVK RhWVFVU Eh IK YKQt hV YhQtE QUQFVEt tTK MAWWKVt YhWVK YQMO MKQEKGKEEGS FVth tTK LQEt
# Rodada 1
# thRhWWhI -0 possibilidades: []
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -4 possibilidades: ['hit', 'hot', 'hat', 'hit']
#  BQWtTKW -4 possibilidades: ['contain', 'mention', 'partner', 'mention']
#  RhWVFVU -1 possibilidades: ['whoever']
#       Eh -3 possibilidades: ['oh', 'ah', 'uh']
#       hV -3 possibilidades: ['he', 'hi', 'ha']
#    YhQtE -3 possibilidades: ['white', 'photo', 'white']
#  QUQFVEt -6 possibilidades: ['against', 'element', 'analyst', 'suspect', 'suspect', 'elegant']
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -7 possibilidades: ['with', 'both', 'both', 'path', 'math', 'myth', 'bath']
#   Identificando EtWKtMT como starter e aplicando no mapa {'E': 's', 'W': 'a', 'K': 'r', 'M': 'e', 'T': 'r'}
#   Ignorando RhWVFVU como whoever por causa de conflitos
# Rodada 2
# thRhWWhI -0 possibilidades: []
#       IK -2 possibilidades: ['or', 'mr']
#   BQEtKW -0 possibilidades: []
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -3 possibilidades: ['hit', 'hot', 'hit']
#      hAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWtTKW -0 possibilidades: []
#     tTKV -0 possibilidades: []
#      hVK -0 possibilidades: []
#     BFVK -5 possibilidades: ['your', 'four', 'door', 'poor', 'pour']
#  RhWVFVU -0 possibilidades: []
#       Eh -0 possibilidades: []
#       IK -2 possibilidades: ['or', 'mr']
#     YKQt -0 possibilidades: []
#       hV -1 possibilidades: ['hi']
#    YhQtE -0 possibilidades: []
#  QUQFVEt -0 possibilidades: []
#      tTK -0 possibilidades: []
#  MAWWKVt -0 possibilidades: []
#    YhWVK -1 possibilidades: ['chair']
#     YQMO -7 possibilidades: ['open', 'view', 'open', 'view', 'fuel', 'poem', 'oven']
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -4 possibilidades: ['with', 'both', 'both', 'myth']
#      tTK -0 possibilidades: []
#   Identificando hV como hi e aplicando no mapa {'V': 'i'}
#   Identificando YhWVK como chair e aplicando no mapa {'Y': 'c'}
# Rodada 3
# thRhWWhI -0 possibilidades: []
#       IK -2 possibilidades: ['or', 'mr']
#     IFGG -5 possibilidades: ['pull', 'full', 'poll', 'doll', 'bull']
#      WAV -0 possibilidades: []
#   BQEtKW -0 possibilidades: []
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -1 possibilidades: ['hot']
#      hAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWtTKW -0 possibilidades: []
#     tTKV -0 possibilidades: []
#      hVK -0 possibilidades: []
#     BFVK -0 possibilidades: []
#  RhWVFVU -0 possibilidades: []
#       Eh -0 possibilidades: []
#       IK -2 possibilidades: ['or', 'mr']
#     YKQt -0 possibilidades: []
#       hV -1 possibilidades: ['hi']
#    YhQtE -0 possibilidades: []
#  QUQFVEt -0 possibilidades: []
#      tTK -0 possibilidades: []
#  MAWWKVt -0 possibilidades: []
#    YhWVK -1 possibilidades: ['chair']
#     YQMO -0 possibilidades: []
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -1 possibilidades: ['with']
#      tTK -0 possibilidades: []
#   Identificando hAt como hot e aplicando no mapa {'A': 'o'}
#   Identificando FVth como with e aplicando no mapa {'F': 'w'}
# Rodada 4
# thRhWWhI -0 possibilidades: []
#       IK -1 possibilidades: ['mr']
#     IFGG -0 possibilidades: []
#      WAV -0 possibilidades: []
#   BQEtKW -0 possibilidades: []
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -1 possibilidades: ['hot']
#      hAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWtTKW -0 possibilidades: []
#     tTKV -0 possibilidades: []
#      hVK -0 possibilidades: []
#     BFVK -0 possibilidades: []
#  RhWVFVU -0 possibilidades: []
#       Eh -0 possibilidades: []
#       IK -1 possibilidades: ['mr']
#     YKQt -0 possibilidades: []
#       hV -1 possibilidades: ['hi']
#    YhQtE -0 possibilidades: []
#  QUQFVEt -0 possibilidades: []
#      tTK -0 possibilidades: []
#  MAWWKVt -0 possibilidades: []
#    YhWVK -1 possibilidades: ['chair']
#     YQMO -0 possibilidades: []
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -1 possibilidades: ['with']
#      tTK -0 possibilidades: []
#     LQEt -4 possibilidades: ['just', 'must', 'just', 'dust']
#   Identificando IK como mr e aplicando no mapa {'I': 'm'}
# Rodada 5
# thRhWWhI -0 possibilidades: []
#       IK -1 possibilidades: ['mr']
#     IFGG -0 possibilidades: []
#      WAV -0 possibilidades: []
#   BQEtKW -0 possibilidades: []
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -1 possibilidades: ['hot']
#      hAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWtTKW -0 possibilidades: []
#     tTKV -0 possibilidades: []
#      hVK -0 possibilidades: []
#     BFVK -0 possibilidades: []
#  RhWVFVU -0 possibilidades: []
#       Eh -0 possibilidades: []
#       IK -1 possibilidades: ['mr']
#     YKQt -0 possibilidades: []
#       hV -1 possibilidades: ['hi']
#    YhQtE -0 possibilidades: []
#  QUQFVEt -0 possibilidades: []
#      tTK -0 possibilidades: []
#  MAWWKVt -0 possibilidades: []
#    YhWVK -1 possibilidades: ['chair']
#     YQMO -0 possibilidades: []
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -1 possibilidades: ['with']
#      tTK -0 possibilidades: []
#     LQEt -3 possibilidades: ['just', 'just', 'dust']
# Mapa em (3):
#  {'D': 't', 'P': 'h', 'E': 's', 'W': 'a', 'K': 'r', 'M': 'e', 'T': 'r', 'V': 'i', 'Y': 'c', 'A': 'o', 'F': 'w', 'I': 'm'}
# Cifra após (3):
#  thRhaahm mr mwGG aoi BQstra starter hot hoa QaRs BQatrra   QiH trri hir Bwir RhaiwiU sh mr crQt hi chQts QUQwist trr eoaarit chair cQeO erQsrGrssGS with trr LQst
# Rodada 1
# thRhWWhI -0 possibilidades: []
#       IK -1 possibilidades: ['mr']
#     IFGG -0 possibilidades: []
#      WAV -0 possibilidades: []
#   BQEtKW -1 possibilidades: ['lustra']
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -1 possibilidades: ['hot']
#      hAW -0 possibilidades: []
#  BQWtTKW -0 possibilidades: []
#     tTKV -0 possibilidades: []
#      hVK -1 possibilidades: ['hir']
#     BFVK -0 possibilidades: []
#  RhWVFVU -0 possibilidades: []
#       Eh -1 possibilidades: ['sh']
#       IK -1 possibilidades: ['mr']
#     YKQt -1 possibilidades: ['crut']
#       hV -1 possibilidades: ['hi']
#    YhQtE -0 possibilidades: []
#  QUQFVEt -0 possibilidades: []
#      tTK -0 possibilidades: []
#  MAWWKVt -0 possibilidades: []
#    YhWVK -1 possibilidades: ['chair']
#     YQMO -5 possibilidades: ['cled', 'clef', 'cleg', 'clep', 'cued']
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -1 possibilidades: ['with']
#      tTK -0 possibilidades: []
#     LQEt -7 possibilidades: ['bust', 'dust', 'fust', 'gust', 'just', 'lust', 'xyst']
#   Identificando BQEtKW como lustra e aplicando no mapa {'B': 'l', 'Q': 'u'}
# Rodada 2
# thRhWWhI -0 possibilidades: []
#       IK -1 possibilidades: ['mr']
#     IFGG -0 possibilidades: []
#      WAV -0 possibilidades: []
#   BQEtKW -1 possibilidades: ['lustra']
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -1 possibilidades: ['hot']
#      hAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWtTKW -0 possibilidades: []
#      QVH -0 possibilidades: []
#     tTKV -0 possibilidades: []
#      hVK -1 possibilidades: ['hir']
#     BFVK -0 possibilidades: []
#  RhWVFVU -0 possibilidades: []
#       Eh -1 possibilidades: ['sh']
#       IK -1 possibilidades: ['mr']
#     YKQt -1 possibilidades: ['crut']
#       hV -1 possibilidades: ['hi']
#    YhQtE -0 possibilidades: []
#  QUQFVEt -0 possibilidades: []
#      tTK -0 possibilidades: []
#  MAWWKVt -0 possibilidades: []
#    YhWVK -1 possibilidades: ['chair']
#     YQMO -1 possibilidades: ['cued']
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -1 possibilidades: ['with']
#      tTK -0 possibilidades: []
#     LQEt -5 possibilidades: ['bust', 'dust', 'fust', 'gust', 'just']
#   Identificando YQMO como cued e aplicando no mapa {'O': 'd'}
# Rodada 3
# thRhWWhI -0 possibilidades: []
#       IK -1 possibilidades: ['mr']
#     IFGG -0 possibilidades: []
#      WAV -0 possibilidades: []
#   BQEtKW -1 possibilidades: ['lustra']
#  EtWKtMT -1 possibilidades: ['starter']
#      hAt -1 possibilidades: ['hot']
#      hAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWtTKW -0 possibilidades: []
#      QVH -0 possibilidades: []
#     tTKV -0 possibilidades: []
#      hVK -1 possibilidades: ['hir']
#     BFVK -0 possibilidades: []
#  RhWVFVU -0 possibilidades: []
#       Eh -1 possibilidades: ['sh']
#       IK -1 possibilidades: ['mr']
#     YKQt -1 possibilidades: ['crut']
#       hV -1 possibilidades: ['hi']
#    YhQtE -0 possibilidades: []
#  QUQFVEt -0 possibilidades: []
#      tTK -0 possibilidades: []
#  MAWWKVt -0 possibilidades: []
#    YhWVK -1 possibilidades: ['chair']
#     YQMO -1 possibilidades: ['cued']
# MKQEKGKEEGS -0 possibilidades: []
#     FVth -1 possibilidades: ['with']
#      tTK -0 possibilidades: []
#     LQEt -4 possibilidades: ['bust', 'fust', 'gust', 'just']
# Mapa em (4):
#  {'D': 't', 'P': 'h', 'E': 's', 'W': 'a', 'K': 'r', 'M': 'e', 'T': 'r', 'V': 'i', 'Y': 'c', 'A': 'o', 'F': 'w', 'I': 'm', 'B': 'l', 'Q': 'u', 'O': 'd'}
# Solução da cifra após (4):
#  thRhaahm mr mwGG aoi lustra starter hot hoa uaRs luatrra   uiH trri hir lwir RhaiwiU sh mr crut hi chuts uUuwist trr eoaarit chair cued erusrGrssGS with trr Lust
# Não há ponto na cifra.
# Nenhum número encontrado na frase.
# Nenhum padrão 't[0-9]s' encontrado.
# Qualidade: 44.83%
# Palavras fora do dicionário: ['thrhaahm', 'mwgg', 'aoi', 'hoa', 'uars', 'luatrra', 'uih', 'trri', 'lwir', 'rhaiwiu', 'chuts', 'uuuwist', 'trr', 'eoaarit', 'erusrgrssgs', 'trr']
# 3
# Cifra após (2):
#  DPRPWWPI Ia IFGG WAV BQEDaW EDWaDMT PAD PAW QWRE BQWDTaW   QVH DTaV PVa BFVa RPWVFVU EP Ia YaQD PV YPQDE QUQFVED DTa MAWWaVD YPWVa YQMO MaQEaGaEEGS FVDP DTa LQED
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ia -1 possibilidades: ['ha']
#  EDWaDMT -1 possibilidades: ['enhance']
#  BQWDTaW -2 possibilidades: ['illegal', 'retreat']
#      PVa -5 possibilidades: ['sea', 'era', 'tea', 'via', 'dna']
#     BFVa -5 possibilidades: ['area', 'idea', 'data', 'sofa', 'plea']
#       Ia -1 possibilidades: ['ha']
#      DTa -5 possibilidades: ['sea', 'era', 'tea', 'via', 'dna']
#  MAWWaVD -8 possibilidades: ['message', 'village', 'passage', 'command', 'command', 'terrain', 'cottage', 'summary']
#    YPWVa -7 possibilidades: ['media', 'extra', 'drama', 'arena', 'opera', 'pizza', 'pasta']
# MaQEaGaEEGS -0 possibilidades: []
#      DTa -5 possibilidades: ['sea', 'era', 'tea', 'via', 'dna']
#   Identificando DPRPWWPI como tomorrow e aplicando no mapa {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w'}
#   Ignorando Ia como ha por causa de conflitos
#   Ignorando EDWaDMT como enhance por causa de conflitos
#   Ignorando Ia como ha por causa de conflitos
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ia -0 possibilidades: []
#     IFGG -5 possibilidades: ['will', 'well', 'wall', 'well', 'will']
#      WAV -7 possibilidades: ['run', 'red', 'run', 'rub', 'rid', 'rip', 'rib']
#   BQEDaW -1 possibilidades: ['guitar']
#  EDWaDMT -0 possibilidades: []
#      PAD -3 possibilidades: ['out', 'out', 'opt']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTaW -0 possibilidades: []
#     DTaV -2 possibilidades: ['than', 'than']
#      PVa -0 possibilidades: []
#     BFVa -2 possibilidades: ['idea', 'plea']
#  RPWVFVU -1 possibilidades: ['morning']
#       Ia -0 possibilidades: []
#       PV -6 possibilidades: ['of', 'on', 'on', 'oh', 'ok', 'ok']
#    YPQDE -2 possibilidades: ['south', 'youth']
#  QUQFVED -5 possibilidades: ['against', 'analyst', 'suspect', 'suspect', 'elegant']
#      DTa -1 possibilidades: ['tea']
#  MAWWaVD -0 possibilidades: []
#    YPWVa -0 possibilidades: []
# MaQEaGaEEGS -0 possibilidades: []
#     FVDP -2 possibilidades: ['into', 'auto']
#      DTa -1 possibilidades: ['tea']
#   Identificando BQEDaW como guitar e aplicando no mapa {'B': 'g', 'Q': 'u', 'E': 'i'}
#   Ignorando PAW como our por causa de conflitos
#   Ignorando QWRE como army por causa de conflitos
#   Ignorando RPWVFVU como morning por causa de conflitos
#   Identificando DTa como tea e aplicando no mapa {'T': 'e'}
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ia -0 possibilidades: []
#     IFGG -1 possibilidades: ['wall']
#      WAV -0 possibilidades: []
#   BQEDaW -1 possibilidades: ['guitar']
#  EDWaDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['opt']
#      PAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWDTaW -0 possibilidades: []
#      QVH -0 possibilidades: []
#     DTaV -0 possibilidades: []
#      PVa -0 possibilidades: []
#     BFVa -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -0 possibilidades: []
#       Ia -0 possibilidades: []
#     YaQD -0 possibilidades: []
#       PV -6 possibilidades: ['of', 'on', 'on', 'oh', 'ok', 'ok']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#  MAWWaVD -0 possibilidades: []
#    YPWVa -0 possibilidades: []
# MaQEaGaEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#     LQED -3 possibilidades: ['suit', 'quit', 'suit']
#   Identificando IFGG como wall e aplicando no mapa {'F': 'a', 'G': 'l'}
#   Identificando PAD como opt e aplicando no mapa {'A': 'p'}
# Rodada 4
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ia -0 possibilidades: []
#     IFGG -1 possibilidades: ['wall']
#      WAV -0 possibilidades: []
#   BQEDaW -1 possibilidades: ['guitar']
#  EDWaDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['opt']
#      PAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWDTaW -0 possibilidades: []
#      QVH -0 possibilidades: []
#     DTaV -0 possibilidades: []
#      PVa -0 possibilidades: []
#     BFVa -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -0 possibilidades: []
#       Ia -0 possibilidades: []
#     YaQD -0 possibilidades: []
#       PV -6 possibilidades: ['of', 'on', 'on', 'oh', 'ok', 'ok']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#  MAWWaVD -0 possibilidades: []
#    YPWVa -0 possibilidades: []
# MaQEaGaEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#     LQED -3 possibilidades: ['suit', 'quit', 'suit']
# Mapa em (3):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'B': 'g', 'Q': 'u', 'E': 'i', 'T': 'e', 'F': 'a', 'G': 'l', 'A': 'p'}
# Cifra após (3):
#  tomorrow wa wall rpV guitar itratMe opt opr urmi gurtear   uVH teaV oVa gaVa morVaVU io wa Yaut oV Youti uUuaVit tea MprraVt YorVa YuMO MauialaiilS aVto tea Luit
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ia -1 possibilidades: ['wa']
#     IFGG -1 possibilidades: ['wall']
#      WAV -1 possibilidades: ['rps']
#   BQEDaW -1 possibilidades: ['guitar']
#  EDWaDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['opt']
#      PAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWDTaW -0 possibilidades: []
#     DTaV -4 possibilidades: ['tead', 'teak', 'tean', 'teas']
#      PVa -6 possibilidades: ['oba', 'oca', 'oda', 'oka', 'ona', 'ova']
#     BFVa -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -1 possibilidades: ['io']
#       Ia -1 possibilidades: ['wa']
#     YaQD -5 possibilidades: ['daut', 'faut', 'haut', 'naut', 'saut']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#  MAWWaVD -0 possibilidades: []
#    YPWVa -4 possibilidades: ['dorsa', 'norna', 'sorda', 'sorva']
# MaQEaGaEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#     LQED -5 possibilidades: ['cuit', 'duit', 'yuit', 'quit', 'suit']
#   Identificando WAV como rps e aplicando no mapa {'V': 's'}
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ia -1 possibilidades: ['wa']
#     IFGG -1 possibilidades: ['wall']
#      WAV -1 possibilidades: ['rps']
#   BQEDaW -1 possibilidades: ['guitar']
#  EDWaDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['opt']
#      PAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWDTaW -0 possibilidades: []
#      QVH -1 possibilidades: ['ush']
#     DTaV -1 possibilidades: ['teas']
#      PVa -0 possibilidades: []
#     BFVa -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -1 possibilidades: ['io']
#       Ia -1 possibilidades: ['wa']
#     YaQD -4 possibilidades: ['daut', 'faut', 'haut', 'naut']
#       PV -1 possibilidades: ['os']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#  MAWWaVD -0 possibilidades: []
#    YPWVa -1 possibilidades: ['dorsa']
# MaQEaGaEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#     LQED -4 possibilidades: ['cuit', 'duit', 'yuit', 'quit']
#   Identificando QVH como ush e aplicando no mapa {'H': 'h'}
#   Identificando YPWVa como dorsa e aplicando no mapa {'Y': 'd'}
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ia -1 possibilidades: ['wa']
#     IFGG -1 possibilidades: ['wall']
#      WAV -1 possibilidades: ['rps']
#   BQEDaW -1 possibilidades: ['guitar']
#  EDWaDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['opt']
#      PAW -0 possibilidades: []
#     QWRE -0 possibilidades: []
#  BQWDTaW -0 possibilidades: []
#      QVH -1 possibilidades: ['ush']
#     DTaV -1 possibilidades: ['teas']
#      PVa -0 possibilidades: []
#     BFVa -0 possibilidades: []
#  RPWVFVU -0 possibilidades: []
#       EP -1 possibilidades: ['io']
#       Ia -1 possibilidades: ['wa']
#     YaQD -1 possibilidades: ['daut']
#       PV -1 possibilidades: ['os']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#  MAWWaVD -0 possibilidades: []
#    YPWVa -1 possibilidades: ['dorsa']
#     YQMO -5 possibilidades: ['dubb', 'duck', 'duff', 'duny', 'dunk']
# MaQEaGaEEGS -0 possibilidades: []
#     FVDP -0 possibilidades: []
#      DTa -1 possibilidades: ['tea']
#     LQED -3 possibilidades: ['cuit', 'yuit', 'quit']
# Mapa em (4):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'B': 'g', 'Q': 'u', 'E': 'i', 'T': 'e', 'F': 'a', 'G': 'l', 'A': 'p', 'V': 's', 'H': 'h', 'Y': 'd'}
# Solução da cifra após (4):
#  tomorrow wa wall rps guitar itratMe opt opr urmi gurtear   ush teas osa gasa morsasU io wa daut os douti uUuasit tea Mprrast dorsa duMO MauialaiilS asto tea Luit
# Não há ponto na cifra.
# Nenhum número encontrado na frase.
# Nenhum padrão 't[0-9]s' encontrado.
# Qualidade: 51.72%
# Palavras fora do dicionário: ['itratme', 'opr', 'urmi', 'gurtear', 'osa', 'gasa', 'morsasu', 'douti', 'uuuasit', 'mprrast', 'dumo', 'mauialaiils', 'asto', 'luit']
# 4
# Cifra após (2):
#  DPRPWWPI Io IFGG WAV BQEDoW EDWoDMT PAD PAW QWRE BQWDToW   QVH DToV PVo BFVo RPWVFVU EP Io YoQD PV YPQDE QUQFVED DTo MAWWoVD YPWVo YQMO MoQEoGoEEGS FVDP DTo LQED
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#  EDWoDMT -0 possibilidades: []
#  BQWDToW -7 possibilidades: ['mention', 'tension', 'symptom', 'warrior', 'pension', 'mention', 'mansion']
#      PVo -8 possibilidades: ['who', 'two', 'too', 'ago', 'ceo', 'pro', 'pro', 'ego']
#     BFVo -6 possibilidades: ['into', 'also', 'onto', 'hero', 'auto', 'echo']
#      DTo -8 possibilidades: ['who', 'two', 'too', 'ago', 'ceo', 'pro', 'pro', 'ego']
#  MAWWoVD -4 possibilidades: ['support', 'support', 'suppose', 'balloon']
#    YPWVo -7 possibilidades: ['radio', 'video', 'photo', 'hello', 'ratio', 'piano', 'cargo']
# MoQEoGoEEGS -0 possibilidades: []
#      DTo -8 possibilidades: ['who', 'two', 'too', 'ago', 'ceo', 'pro', 'pro', 'ego']
#   Identificando DPRPWWPI como tomorrow e aplicando no mapa {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w'}
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Io -0 possibilidades: []
#     IFGG -5 possibilidades: ['will', 'well', 'wall', 'well', 'will']
#      WAV -7 possibilidades: ['run', 'red', 'run', 'rub', 'rid', 'rip', 'rib']
#   BQEDoW -4 possibilidades: ['factor', 'editor', 'sector', 'pastor']
#  EDWoDMT -0 possibilidades: []
#      PAD -3 possibilidades: ['out', 'out', 'opt']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDToW -0 possibilidades: []
#     DToV -0 possibilidades: []
#      PVo -0 possibilidades: []
#     BFVo -2 possibilidades: ['also', 'echo']
#  RPWVFVU -1 possibilidades: ['morning']
#       Io -0 possibilidades: []
#       PV -6 possibilidades: ['of', 'on', 'on', 'oh', 'ok', 'ok']
#    YPQDE -2 possibilidades: ['south', 'youth']
#  QUQFVED -5 possibilidades: ['against', 'analyst', 'suspect', 'suspect', 'elegant']
#      DTo -0 possibilidades: []
#  MAWWoVD -0 possibilidades: []
#    YPWVo -0 possibilidades: []
# MoQEoGoEEGS -0 possibilidades: []
#     FVDP -2 possibilidades: ['into', 'auto']
#      DTo -0 possibilidades: []
#   Identificando PAW como our e aplicando no mapa {'A': 'u'}
#   Identificando QWRE como army e aplicando no mapa {'Q': 'a', 'E': 'y'}
#   Identificando RPWVFVU como morning e aplicando no mapa {'V': 'n', 'F': 'i', 'U': 'g'}
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Io -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'will']
#      WAV -2 possibilidades: ['run', 'run']
#   BQEDoW -0 possibilidades: []
#  EDWoDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDToW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DToV -0 possibilidades: []
#      PVo -0 possibilidades: []
#     BFVo -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -0 possibilidades: []
#       Io -0 possibilidades: []
#     YoQD -2 possibilidades: ['boat', 'coat']
#       PV -2 possibilidades: ['on', 'on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTo -0 possibilidades: []
#  MAWWoVD -0 possibilidades: []
#    YPWVo -0 possibilidades: []
# MoQEoGoEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTo -0 possibilidades: []
#     LQED -0 possibilidades: []
#   Identificando QVH como and e aplicando no mapa {'H': 'd'}
# Rodada 4
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Io -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'will']
#      WAV -2 possibilidades: ['run', 'run']
#   BQEDoW -0 possibilidades: []
#  EDWoDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDToW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DToV -0 possibilidades: []
#      PVo -0 possibilidades: []
#     BFVo -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -0 possibilidades: []
#       Io -0 possibilidades: []
#     YoQD -2 possibilidades: ['boat', 'coat']
#       PV -2 possibilidades: ['on', 'on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTo -0 possibilidades: []
#  MAWWoVD -0 possibilidades: []
#    YPWVo -0 possibilidades: []
# MoQEoGoEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTo -0 possibilidades: []
#     LQED -0 possibilidades: []
# Mapa em (3):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'V': 'n', 'F': 'i', 'U': 'g', 'H': 'd'}
# Cifra após (3):
#  tomorrow wo wiGG run Baytor ytrotMT out our army BartTor   and tTon ono Bino morning yo wo Yoat on Yoaty againyt tTo Murront Yorno YaMO MoayoGoyyGS into tTo Layt
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Io -1 possibilidades: ['wo']
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDoW -0 possibilidades: []
#  EDWoDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDToW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DToV -1 possibilidades: ['thon']
#      PVo -1 possibilidades: ['ono']
#     BFVo -6 possibilidades: ['bino', 'fino', 'kino', 'lino', 'pino', 'vino']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       Io -1 possibilidades: ['wo']
#     YoQD -2 possibilidades: ['boat', 'coat']
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTo -2 possibilidades: ['tho', 'tlo']
#  MAWWoVD -0 possibilidades: []
#    YPWVo -2 possibilidades: ['corno', 'porno']
# MoQEoGoEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTo -2 possibilidades: ['tho', 'tlo']
#     LQED -1 possibilidades: ['payt']
#   Identificando DToV como thon e aplicando no mapa {'T': 'h'}
#   Identificando LQED como payt e aplicando no mapa {'L': 'p'}
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Io -1 possibilidades: ['wo']
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDoW -0 possibilidades: []
#  EDWoDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDToW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DToV -1 possibilidades: ['thon']
#      PVo -1 possibilidades: ['ono']
#     BFVo -5 possibilidades: ['bino', 'fino', 'kino', 'lino', 'vino']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       Io -1 possibilidades: ['wo']
#     YoQD -2 possibilidades: ['boat', 'coat']
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTo -1 possibilidades: ['tho']
#  MAWWoVD -0 possibilidades: []
#    YPWVo -1 possibilidades: ['corno']
# MoQEoGoEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTo -1 possibilidades: ['tho']
#     LQED -1 possibilidades: ['payt']
#   Identificando YPWVo como corno e aplicando no mapa {'Y': 'c'}
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Io -1 possibilidades: ['wo']
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDoW -0 possibilidades: []
#  EDWoDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDToW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DToV -1 possibilidades: ['thon']
#      PVo -1 possibilidades: ['ono']
#     BFVo -5 possibilidades: ['bino', 'fino', 'kino', 'lino', 'vino']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       Io -1 possibilidades: ['wo']
#     YoQD -1 possibilidades: ['coat']
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTo -1 possibilidades: ['tho']
#  MAWWoVD -0 possibilidades: []
#    YPWVo -1 possibilidades: ['corno']
# MoQEoGoEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTo -1 possibilidades: ['tho']
#     LQED -1 possibilidades: ['payt']
# Mapa em (4):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'V': 'n', 'F': 'i', 'U': 'g', 'H': 'd', 'T': 'h', 'L': 'p', 'Y': 'c'}
# Solução da cifra após (4):
#  tomorrow wo wiGG run Baytor ytrotMh out our army Barthor   and thon ono Bino morning yo wo coat on coaty againyt tho Murront corno caMO MoayoGoyyGS into tho payt
# Não há ponto na cifra.
# Nenhum número encontrado na frase.
# Nenhum padrão 't[0-9]s' encontrado.
# Qualidade: 68.97%
# Palavras fora do dicionário: ['wigg', 'baytor', 'ytrotmh', 'barthor', 'coaty', 'againyt', 'murront', 'camo', 'moayogoyygs']
# 5
# Cifra após (2):
#  DPRPWWPI Ii IFGG WAV BQEDiW EDWiDMT PAD PAW QWRE BQWDTiW   QVH DTiV PVi BFVi RPWVFVU EP Ii YiQD PV YPQDE QUQFVED DTi MAWWiVD YPWVi YQMO MiQEiGiEEGS FVDP DTi LQED
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ii -1 possibilidades: ['hi']
#  EDWiDMT -2 possibilidades: ['believe', 'relieve']
#  BQWDTiW -1 possibilidades: ['contain']
#      PVi -1 possibilidades: ['ski']
#     BFVi -0 possibilidades: []
#       Ii -1 possibilidades: ['hi']
#      DTi -1 possibilidades: ['ski']
#    YPWVi -1 possibilidades: ['iraqi']
# MiQEiGiEEGS -0 possibilidades: []
#      DTi -1 possibilidades: ['ski']
#   Identificando DPRPWWPI como tomorrow e aplicando no mapa {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w'}
#   Ignorando Ii como hi por causa de conflitos
#   Ignorando BQWDTiW como contain por causa de conflitos
#   Ignorando PVi como ski por causa de conflitos
#   Ignorando Ii como hi por causa de conflitos
#   Ignorando DTi como ski por causa de conflitos
#   Ignorando YPWVi como iraqi por causa de conflitos
#   Ignorando DTi como ski por causa de conflitos
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ii -0 possibilidades: []
#     IFGG -5 possibilidades: ['will', 'well', 'wall', 'well', 'will']
#      WAV -7 possibilidades: ['run', 'red', 'run', 'rub', 'rid', 'rip', 'rib']
#   BQEDiW -0 possibilidades: []
#  EDWiDMT -0 possibilidades: []
#      PAD -3 possibilidades: ['out', 'out', 'opt']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTiW -0 possibilidades: []
#     DTiV -4 possibilidades: ['this', 'thin', 'tail', 'this']
#      PVi -0 possibilidades: []
#     BFVi -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       Ii -0 possibilidades: []
#     YiQD -7 possibilidades: ['list', 'lift', 'gift', 'list', 'diet', 'fist', 'hint']
#       PV -6 possibilidades: ['of', 'on', 'on', 'oh', 'ok', 'ok']
#    YPQDE -2 possibilidades: ['south', 'youth']
#  QUQFVED -5 possibilidades: ['against', 'analyst', 'suspect', 'suspect', 'elegant']
#      DTi -0 possibilidades: []
#  MAWWiVD -0 possibilidades: []
#    YPWVi -0 possibilidades: []
# MiQEiGiEEGS -0 possibilidades: []
#     FVDP -2 possibilidades: ['into', 'auto']
#      DTi -0 possibilidades: []
#   Identificando PAW como our e aplicando no mapa {'A': 'u'}
#   Identificando QWRE como army e aplicando no mapa {'Q': 'a', 'E': 'y'}
#   Identificando RPWVFVU como morning e aplicando no mapa {'V': 'n', 'F': 'i', 'U': 'g'}
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ii -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'will']
#      WAV -2 possibilidades: ['run', 'run']
#   BQEDiW -0 possibilidades: []
#  EDWiDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTiW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTiV -1 possibilidades: ['thin']
#      PVi -0 possibilidades: []
#     BFVi -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -0 possibilidades: []
#       Ii -0 possibilidades: []
#     YiQD -0 possibilidades: []
#       PV -2 possibilidades: ['on', 'on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTi -0 possibilidades: []
#  MAWWiVD -0 possibilidades: []
#    YPWVi -0 possibilidades: []
# MiQEiGiEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTi -0 possibilidades: []
#     LQED -0 possibilidades: []
#   Identificando QVH como and e aplicando no mapa {'H': 'd'}
#   Identificando DTiV como thin e aplicando no mapa {'T': 'h'}
# Rodada 4
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ii -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'will']
#      WAV -2 possibilidades: ['run', 'run']
#   BQEDiW -0 possibilidades: []
#  EDWiDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTiW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTiV -1 possibilidades: ['thin']
#      PVi -0 possibilidades: []
#     BFVi -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -0 possibilidades: []
#       Ii -0 possibilidades: []
#     YiQD -0 possibilidades: []
#       PV -2 possibilidades: ['on', 'on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTi -0 possibilidades: []
#  MAWWiVD -0 possibilidades: []
#    YPWVi -0 possibilidades: []
# MiQEiGiEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTi -0 possibilidades: []
#     LQED -0 possibilidades: []
# Mapa em (3):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'V': 'n', 'F': 'i', 'U': 'g', 'H': 'd', 'T': 'h'}
# Cifra após (3):
#  tomorrow wi wiGG run Baytir ytritMh out our army Barthir   and thin oni Bini morning yo wi Yiat on Yoaty againyt thi Murrint Yorni YaMO MiayiGiyyGS into thi Layt
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ii -1 possibilidades: ['wi']
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDiW -0 possibilidades: []
#  EDWiDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTiW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTiV -1 possibilidades: ['thin']
#      PVi -1 possibilidades: ['oni']
#     BFVi -2 possibilidades: ['bini', 'fini']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       Ii -1 possibilidades: ['wi']
#     YiQD -1 possibilidades: ['fiat']
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTi -0 possibilidades: []
#  MAWWiVD -0 possibilidades: []
#    YPWVi -0 possibilidades: []
# MiQEiGiEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTi -0 possibilidades: []
#     LQED -1 possibilidades: ['payt']
#   Identificando YiQD como fiat e aplicando no mapa {'Y': 'f'}
#   Identificando LQED como payt e aplicando no mapa {'L': 'p'}
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ii -1 possibilidades: ['wi']
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDiW -0 possibilidades: []
#  EDWiDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTiW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTiV -1 possibilidades: ['thin']
#      PVi -1 possibilidades: ['oni']
#     BFVi -1 possibilidades: ['bini']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       Ii -1 possibilidades: ['wi']
#     YiQD -1 possibilidades: ['fiat']
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTi -0 possibilidades: []
#  MAWWiVD -0 possibilidades: []
#    YPWVi -0 possibilidades: []
# MiQEiGiEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTi -0 possibilidades: []
#     LQED -1 possibilidades: ['payt']
#   Identificando BFVi como bini e aplicando no mapa {'B': 'b'}
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       Ii -1 possibilidades: ['wi']
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDiW -0 possibilidades: []
#  EDWiDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTiW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTiV -1 possibilidades: ['thin']
#      PVi -1 possibilidades: ['oni']
#     BFVi -1 possibilidades: ['bini']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       Ii -1 possibilidades: ['wi']
#     YiQD -1 possibilidades: ['fiat']
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTi -0 possibilidades: []
#  MAWWiVD -0 possibilidades: []
#    YPWVi -0 possibilidades: []
# MiQEiGiEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTi -0 possibilidades: []
#     LQED -1 possibilidades: ['payt']
# Mapa em (4):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'V': 'n', 'F': 'i', 'U': 'g', 'H': 'd', 'T': 'h', 'Y': 'f', 'L': 'p', 'B': 'b'}
# Solução da cifra após (4):
#  tomorrow wi wiGG run baytir ytritMh out our army barthir   and thin oni bini morning yo wi fiat on foaty againyt thi Murrint forni faMO MiayiGiyyGS into thi payt
# Não há ponto na cifra.
# Nenhum número encontrado na frase.
# Nenhum padrão 't[0-9]s' encontrado.
# Qualidade: 58.62%
# Palavras fora do dicionário: ['wigg', 'baytir', 'ytritmh', 'barthir', 'foaty', 'againyt', 'thi', 'murrint', 'forni', 'famo', 'miayigiyygs', 'thi']
# 6
# Cifra após (2):
#  DPRPWWPI In IFGG WAV BQEDnW EDWnDMT PAD PAW QWRE BQWDTnW   QVH DTnV PVn BFVn RPWVFVU EP In YnQD PV YPQDE QUQFVED DTn MAWWnVD YPWVn YQMO MnQEnGnEEGS FVDP DTn LQED
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       In -5 possibilidades: ['in', 'on', 'in', 'on', 'in']
#  EDWnDMT -1 possibilidades: ['dignity']
#  BQWDTnW -3 possibilidades: ['patient', 'ongoing', 'patient']
#       In -5 possibilidades: ['in', 'on', 'in', 'on', 'in']
#  MAWWnVD -0 possibilidades: []
# MnQEnGnEEGS -0 possibilidades: []
#   Identificando DPRPWWPI como tomorrow e aplicando no mapa {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w'}
#   Ignorando EDWnDMT como dignity por causa de conflitos
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       In -0 possibilidades: []
#     IFGG -5 possibilidades: ['will', 'well', 'wall', 'well', 'will']
#      WAV -7 possibilidades: ['run', 'red', 'run', 'rub', 'rid', 'rip', 'rib']
#   BQEDnW -0 possibilidades: []
#  EDWnDMT -0 possibilidades: []
#      PAD -3 possibilidades: ['out', 'out', 'opt']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTnW -0 possibilidades: []
#     DTnV -5 possibilidades: ['tend', 'tiny', 'tank', 'tune', 'tune']
#      PVn -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       In -0 possibilidades: []
#     YnQD -1 possibilidades: ['unit']
#       PV -6 possibilidades: ['of', 'on', 'on', 'oh', 'ok', 'ok']
#    YPQDE -2 possibilidades: ['south', 'youth']
#  QUQFVED -5 possibilidades: ['against', 'analyst', 'suspect', 'suspect', 'elegant']
#      DTn -1 possibilidades: ['ten']
#  MAWWnVD -0 possibilidades: []
#    YPWVn -0 possibilidades: []
# MnQEnGnEEGS -0 possibilidades: []
#     FVDP -2 possibilidades: ['into', 'auto']
#      DTn -1 possibilidades: ['ten']
#   Identificando PAW como our e aplicando no mapa {'A': 'u'}
#   Identificando QWRE como army e aplicando no mapa {'Q': 'a', 'E': 'y'}
#   Identificando RPWVFVU como morning e aplicando no mapa {'V': 'n', 'F': 'i', 'U': 'g'}
#   Ignorando YnQD como unit por causa de conflitos
#   Identificando DTn como ten e aplicando no mapa {'T': 'e'}
# Rodada 3
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       In -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'will']
#      WAV -2 possibilidades: ['run', 'run']
#   BQEDnW -0 possibilidades: []
#  EDWnDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTnW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTnV -0 possibilidades: []
#      PVn -0 possibilidades: []
#     BFVn -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -0 possibilidades: []
#       In -0 possibilidades: []
#     YnQD -0 possibilidades: []
#       PV -2 possibilidades: ['on', 'on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTn -1 possibilidades: ['ten']
#  MAWWnVD -0 possibilidades: []
#    YPWVn -0 possibilidades: []
# MnQEnGnEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTn -1 possibilidades: ['ten']
#     LQED -0 possibilidades: []
#   Identificando QVH como and e aplicando no mapa {'H': 'd'}
# Rodada 4
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       In -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'will']
#      WAV -2 possibilidades: ['run', 'run']
#   BQEDnW -0 possibilidades: []
#  EDWnDMT -0 possibilidades: []
#      PAD -2 possibilidades: ['out', 'out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTnW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTnV -0 possibilidades: []
#      PVn -0 possibilidades: []
#     BFVn -0 possibilidades: []
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -0 possibilidades: []
#       In -0 possibilidades: []
#     YnQD -0 possibilidades: []
#       PV -2 possibilidades: ['on', 'on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTn -1 possibilidades: ['ten']
#  MAWWnVD -0 possibilidades: []
#    YPWVn -0 possibilidades: []
# MnQEnGnEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTn -1 possibilidades: ['ten']
#     LQED -0 possibilidades: []
# Mapa em (3):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'V': 'n', 'F': 'i', 'U': 'g', 'T': 'e', 'H': 'd'}
# Cifra após (3):
#  tomorrow wn wiGG run Baytnr ytrntMe out our army Bartenr   and tenn onn Binn morning yo wn Ynat on Yoaty againyt ten Murrnnt Yornn YaMO MnaynGnyyGS into ten Layt
# Rodada 1
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       In -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDnW -0 possibilidades: []
#  EDWnDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTnW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTnV -0 possibilidades: []
#      PVn -0 possibilidades: []
#     BFVn -3 possibilidades: ['finn', 'jinn', 'linn']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       In -0 possibilidades: []
#     YnQD -0 possibilidades: []
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTn -1 possibilidades: ['ten']
#  MAWWnVD -0 possibilidades: []
#    YPWVn -0 possibilidades: []
# MnQEnGnEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTn -1 possibilidades: ['ten']
#     LQED -1 possibilidades: ['payt']
#   Identificando LQED como payt e aplicando no mapa {'L': 'p'}
# Rodada 2
# DPRPWWPI -1 possibilidades: ['tomorrow']
#       In -0 possibilidades: []
#     IFGG -2 possibilidades: ['will', 'wiss']
#      WAV -1 possibilidades: ['run']
#   BQEDnW -0 possibilidades: []
#  EDWnDMT -0 possibilidades: []
#      PAD -1 possibilidades: ['out']
#      PAW -1 possibilidades: ['our']
#     QWRE -1 possibilidades: ['army']
#  BQWDTnW -0 possibilidades: []
#      QVH -1 possibilidades: ['and']
#     DTnV -0 possibilidades: []
#      PVn -0 possibilidades: []
#     BFVn -3 possibilidades: ['finn', 'jinn', 'linn']
#  RPWVFVU -1 possibilidades: ['morning']
#       EP -1 possibilidades: ['yo']
#       In -0 possibilidades: []
#     YnQD -0 possibilidades: []
#       PV -1 possibilidades: ['on']
#    YPQDE -0 possibilidades: []
#  QUQFVED -0 possibilidades: []
#      DTn -1 possibilidades: ['ten']
#  MAWWnVD -0 possibilidades: []
#    YPWVn -0 possibilidades: []
# MnQEnGnEEGS -0 possibilidades: []
#     FVDP -1 possibilidades: ['into']
#      DTn -1 possibilidades: ['ten']
#     LQED -1 possibilidades: ['payt']
# Mapa em (4):
#  {'D': 't', 'P': 'o', 'R': 'm', 'W': 'r', 'I': 'w', 'A': 'u', 'Q': 'a', 'E': 'y', 'V': 'n', 'F': 'i', 'U': 'g', 'T': 'e', 'H': 'd', 'L': 'p'}
# Solução da cifra após (4):
#  tomorrow wn wiGG run Baytnr ytrntMe out our army Bartenr   and tenn onn Binn morning yo wn Ynat on Yoaty againyt ten Murrnnt Yornn YaMO MnaynGnyyGS into ten payt
# Não há ponto na cifra.
# Nenhum número encontrado na frase.
# Nenhum padrão 't[0-9]s' encontrado.
# Qualidade: 44.83%
# Palavras fora do dicionário: ['wn', 'wigg', 'baytnr', 'ytrntme', 'bartenr', 'tenn', 'onn', 'binn', 'wn', 'ynat', 'yoaty', 'againyt', 'murrnnt', 'yornn', 'yamo', 'mnayngnyygs']
# Tempo de execução: 17.48200 segundos
